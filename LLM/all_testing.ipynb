# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
# Data ingestion
from langchain_community.document_loaders import WebBaseLoader 
loader=WebBaseLoader("https://en.wikipedia.org/wiki/Bhagat_Singh")
docs=loader.load()
docs
# Out:
# [Document(metadata={'source': 'https://en.wikipedia.org/wiki/Bhagat_Singh', 'title': 'Bhagat Singh - Wikipedia', 'language': 'en'}, page_content='\n\n\n\nBhagat Singh - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJump to content\n\n\n\n\n\n\n\nMain menu\n\n\n\n\n\nMain menu\nmove to sidebar\nhide\n\n\n\n\t\tNavigation\n\t\n\n\nMain pageContentsCurrent eventsRandom articleAbout WikipediaContact us\n\n\n\n\n\n\t\tContribute\n\t\n\n\nHelpLearn to editCommunity portalRecent changesUpload file\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAppearance\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDonate\n\nCreate account\n\nLog in\n\n\n\n\n\n\n\n\nPersonal tools\n\n\n\n\n\nDonate Create account Log in\n\n\n\n\n\n\t\tPages for logged out editors learn more\n\n\n\nContributionsTalk\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nContents\nmove to sidebar\nhide\n\n\n\n\n(Top)\n\n\n\n\n\n
# ...

# %%
# Chunks
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=50)
documents=text_splitter.split_documents(docs)
documents
# Out:
# [Document(metadata={'source': 'https://en.wikipedia.org/wiki/Bhagat_Singh', 'title': 'Bhagat Singh - Wikipedia', 'language': 'en'}, page_content='Bhagat Singh - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJump to content\n\n\n\n\n\n\n\nMain menu\n\n\n\n\n\nMain menu\nmove to sidebar\nhide\n\n\n\n\t\tNavigation\n\t\n\n\nMain pageContentsCurrent eventsRandom articleAbout WikipediaContact us\n\n\n\n\n\n\t\tContribute\n\t\n\n\nHelpLearn to editCommunity portalRecent changesUpload file\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAppearance\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDonate\n\nCreate account\n\nLog in\n\n\n\n\n\n\n\n\nPersonal tools\n\n\n\n\n\nDonate Create account Log in\n\n\n\n\n\n\t\tPages for logged out editors learn more\n\n\n\nContributionsTalk\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nContents\nmove to sidebar\nhide\n\n\n\n\n(Top)\n\n\n\n\n\n1\nEarly
# ...

# %%
# Embeddings
from langchain_openai import OpenAIEmbeddings
embeddings=OpenAIEmbeddings()

# %%
# Vector DB
from langchain_community.vectorstores import FAISS
vectorstoredb=FAISS.from_documents(documents,embeddings)
vectorstoredb

# %%
query="Why Bhagat singh hanged?"
result=vectorstoredb.simila
result[0].page_content
# Out:
# 'Bhagat Singh and his two associates have been hanged. The Congress made many attempts to save their lives and the Government entertained many hopes of it, but all has been in a vain.\nBhagat Singh did not wish to live. He refused to apologise, or even file an appeal. Bhagat Singh was not a devotee of non-violence, but he did not subscribe to the religion of violence. He took to violence due to helplessness and to defend his homeland. In his last letter, Bhagat Singh wrote, " I have been arrested while waging a war. For me there can be no gallows. Put me into the mouth of a cannon and blow me off." These heroes had conquered the fear of death. Let us bow to them a thousand times for their heroism.'

# %%
from datetime import datetime

# Sample Unix timestamp
unix_timestamp = 1727873795  # replace with your actual timestamp

# Convert to readable format
readable_datetime = datetime.fromtimestamp(unix_timestamp).strftime('%Y-%m-%d %H:%M:%S')

print("Readable DateTime:", readable_datetime)
# Out:
# Readable DateTime: 2024-10-02 18:26:35

# %%
import pandas as pd

x = "2024-09-28T17:51:00.000Z"
y = "2024-09-28 18:52:35"

hours = round((pd.to_datetime(y).tz_localize('UTC') - pd.to_datetime(x).tz_convert('UTC')).total_seconds() / 3600, 2)

hours
# Out:
# 1.03

# %%
import re
X="KL343242456"
result = int(re.search(r'\d+', X).group())
result
# Out:
# 343242456

# %%
from datetime import datetime
import datetime
formatted_time = datetime.datetime(2024, 9, 27, 19, 29).strftime('%Y-%m-%dT%H:%M:%S.000Z')

# %%
formatted_time
# Out:
# '2024-09-27T19:29:00.000Z'

# %%
def clean_input_string(x):
    # Remove single and double quotes
    cleaned_string = x.replace("'", "").replace('"', '')
    return cleaned_string

# Example usage:
x = """sooraj.sr@cloud4c.com', 'ranjith.pattanath@cloud4c.com', 'yashwanth.mula@cloud4c.com', 'mayur.tarle@cloud4c.com', 'koundinya.kosuri@cloud4c.com', 'raviraj.k@cloud4c.com', 'vernin.nazareth@cloud4c.com', 'saisaroj.bandoju@cloud4c.com', 'bhanuprakash.kovuri@cloud4c.com', 'subhani.shaikmahaboob@cloud4c.com', 'sirichandana.yarra@cloud4c.com', 'chandrashekhar.matham@cloud4c.com', 'sandhya.nadimidoddi@cloud4c.com', 'darshan.vyas@cloud4c.com', 'anwar.ahamed@cloud4c.com', 'nikhil.parki@cloud4c.com', 'nilesh.gupta@cloud4c.com', 'praveen.kumar@cloud4c.com', 'naresh.jammu@cloud4c.com', 'shanker.puli@cloud4c.com', 'madhuri.thirumalasetty@cloud4c.com'"""
result = clean_input_string(x)
print(result)
# Out:
# sooraj.sr@cloud4c.com, ranjith.pattanath@cloud4c.com, yashwanth.mula@cloud4c.com, mayur.tarle@cloud4c.com, koundinya.kosuri@cloud4c.com, raviraj.k@cloud4c.com, vernin.nazareth@cloud4c.com, saisaroj.bandoju@cloud4c.com, bhanuprakash.kovuri@cloud4c.com, subhani.shaikmahaboob@cloud4c.com, sirichandana.yarra@cloud4c.com, chandrashekhar.matham@cloud4c.com, sandhya.nadimidoddi@cloud4c.com, darshan.vyas@cloud4c.com, anwar.ahamed@cloud4c.com, nikhil.parki@cloud4c.com, nilesh.gupta@cloud4c.com, praveen.kumar@cloud4c.com, naresh.jammu@cloud4c.com, shanker.puli@cloud4c.com, madhuri.thirumalasetty@cloud4c.com

# %%
from langchain.embeddings import OpenAIEmbeddings

# Set your OpenAI API key
#openai.api_key = 'your_openai_api_key'

# Initialize OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")

# Sample text
text = "OpenAI provides powerful tools for natural language processing dfsfgdf."

# Generate embeddings
embedding_vector = embeddings.embed_query(text)
print("Embedding vector:", embedding_vector)
# Out:
# Embedding vector: [-0.010783945752899699, 0.007842253610944448, -0.012749592314064842, -0.010695830533323665, -0.0017419697787441446, 0.015779399675596124, -0.013102053192368976, 0.001583531907492818, 0.0068865420608542815, -0.03988229712141674, 0.018951547580333336, 0.02239481837792984, 0.004219362825807737, 0.0009345294920089463, -0.0007892241417012579, 0.013264727300613571, 0.016294534662144852, -0.008343832266585704, 0.005303857656873815, -0.00039736567146238, -0.005351304349388701, 0.009577444409327633, -0.029091573203063312, -0.0181788441691877, -0.005707153844758433, 0.0067170897871559505, 0.01812461884555781, -0.028983124418448608, -0.010465374770541705, -0.014355999831472115, 0.020957862202898355, -0.01129230257399469, -0.005785102281815132, -0.009272430689199654, -0.01846352339295447, 0.0151829276349251, 0.0014937221465533505, -0.009211428131438567, 0.010973731591636697, -0.0039245154225378215, 0.01930400845863747, 0.005412306907149788, -0.002297773408769339, -0.03380912420
# ...
